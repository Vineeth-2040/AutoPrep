# %%
from main import *
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading data frame
path='data/Titanic-Dataset.csv'
df=load_data(path)
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df=drop_columns(df,['PassengerId'])
df.shape
# Out:
# (891, 11)

# %%
# drop missing target 
df=drop_missing_target(df,'Survived')
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# check missing 
result=check_missing(df)
print(result)
df.shape
# Out:
#    column_name  total_missing  percentage_missing
# 0     Survived              0                0.00
# 1       Pclass              0                0.00
# 2         Name              0                0.00
# 3          Sex              0                0.00
# 4          Age            177               19.87
# 5        SibSp              0                0.00
# 6        Parch              0                0.00
# 7       Ticket              0                0.00
# 8         Fare              0                0.00
# 9        Cabin            687               77.10
# 10    Embarked              2                0.22
# (891, 11)

# %%
# drop missing above threshold
df=drop_threshold(df,result,30)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %%
report2=check_missing(df)
print(report2)
# Out:
#   column_name  total_missing  percentage_missing
# 0    Survived              0                0.00
# 1      Pclass              0                0.00
# 2        Name              0                0.00
# 3         Sex              0                0.00
# 4         Age            177               19.87
# 5       SibSp              0                0.00
# 6       Parch              0                0.00
# 7      Ticket              0                0.00
# 8        Fare              0                0.00
# 9    Embarked              2                0.22

# %%
# info
col_report=detect_column_types(df,'Survived')
print(col_report)
# Out:
# {'numerical': ['Age', 'Fare'], 'categorical': ['Name', 'Sex', 'Embarked'], 'datetime': [], 'mixed': ['Ticket'], 'encoded_categorical': ['Pclass', 'SibSp', 'Parch'], 'target': {'name': 'Survived', 'type': 'numerical'}}

# %%
x,y=prepare_x_y(df,'Survived',col_report['mixed'],col_report['datetime'])
print(x.head())
print(y.head())
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch     Fare Embarked
# 0      1      0   7.2500        S
# 1      1      0  71.2833        C
# 2      0      0   7.9250        S
# 3      1      0  53.1000        S
# 4      0      0   8.0500        S
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
print(col_report['numerical'])
trans=get_valid_transformers(x,col_report['numerical'])
print(trans)
# Out:
# ['Age', 'Fare']
# [('passthrough', 'passthrough'), ('yeojohnson', PowerTransformer()), ('log', FunctionTransformer(func=<ufunc 'log1p'>)), ('sqrt', FunctionTransformer(func=<ufunc 'sqrt'>))]

# %%
tranformers=get_valid_transformers(df,col_report['numerical'])

# %%
result_df=run_experiments(x,y,col_report['numerical'],col_report['categorical'],col_report['encoded_categorical'],numerical_imputers,categorical_imputers,encoders,tranformers,scalers)
# Out:
# [1/1296] mean | most_frequent | onehot | passthrough | passthrough →
# r2 = 0.8025 ± 0.0255
# [2/1296] mean | most_frequent | onehot | passthrough | standard → r2 = 0.8036 ± 0.0244
# [3/1296] mean | most_frequent | onehot | passthrough | minmax → r2 = 0.7980 ± 0.0219
# [4/1296] mean | most_frequent | onehot | passthrough | robust → r2 = 0.8036 ± 0.0244
# [5/1296] mean | most_frequent | onehot | passthrough | maxabs → r2 = 0.7980 ± 0.0219
# [6/1296] mean | most_frequent | onehot | passthrough | mean_normalisation → r2 = 0.7957 ± 0.0257
# [7/1296] mean | most_frequent | onehot | yeojohnson | passthrough → r2 = 0.7957 ± 0.0277
# [8/1296] mean | most_frequent | onehot | yeojohnson | standard → r2 = 0.7957 ± 0.0277
# [9/1296] mean | most_frequent | onehot | yeojohnson | minmax → r2 = 0.8002 ± 0.0226
# [10/1296] mean | most_frequent | onehot | yeojohnson | robust → r2 = 0.7969 ± 0.0269
# [11/1296] mean | most_frequent | onehot | yeojohnson | maxabs → r2 = 0.7957 ± 0.0263
# ...

# %%
show_results(result_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 show_results(result_df)
#
# NameError: name 'result_df' is not defined
